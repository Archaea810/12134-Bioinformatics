# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('WHO-COVID-19-global-data.csv')
df.loc[df['New_deaths'] < 0, 'New_deaths'] = 0
df.loc[df['New_cases'] < 0, 'New_cases'] = 0

# %%
df[df['Country_code']=='BR']
# Out:
#       Date_reported Country_code Country WHO_region  New_cases
# 33488    2020-01-03           BR  Brazil       AMRO          0  \
# 33489    2020-01-04           BR  Brazil       AMRO          0
# 33490    2020-01-05           BR  Brazil       AMRO          0
# 33491    2020-01-06           BR  Brazil       AMRO          0
# 33492    2020-01-07           BR  Brazil       AMRO          0
# ...             ...          ...     ...        ...        ...
# 34679    2023-04-08           BR  Brazil       AMRO          0
# 34680    2023-04-09           BR  Brazil       AMRO      60591
# 34681    2023-04-10           BR  Brazil       AMRO          0
# 34682    2023-04-11           BR  Brazil       AMRO          0
# 34683    2023-04-12           BR  Brazil       AMRO          0
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 33488                 0           0                  0
# 33489                 0           0                  0
# ...

# %%
df[df['Date_reported']=='2020-03-11'][df['Country_code']=='BR'] #Original pandemic declaration
# Out:
# /var/folders/mn/7pmlfsp175s9b73sjyf7qyvc0000gn/T/ipykernel_4196/1494737242.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Date_reported']=='2020-03-11'][df['Country_code']=='BR'] #Original pandemic declaration
#       Date_reported Country_code Country WHO_region  New_cases
# 33556    2020-03-11           BR  Brazil       AMRO          0  \
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 33556                25           0                  0

# %%
df[df['Date_reported']=='2020-12-18'][df['Country_code']=='BR'] #Alpha
# Out:
# /var/folders/mn/7pmlfsp175s9b73sjyf7qyvc0000gn/T/ipykernel_4196/3501272361.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Date_reported']=='2020-12-18'][df['Country_code']=='BR'] #Alpha
#       Date_reported Country_code Country WHO_region  New_cases
# 33838    2020-12-18           BR  Brazil       AMRO      70574  \
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 33838           7040608         936             183735

# %%
df[df['Date_reported']=='2021-01-11'][df['Country_code']=='BR'] #Original pandemic declaration
# Out:
# /var/folders/mn/7pmlfsp175s9b73sjyf7qyvc0000gn/T/ipykernel_4196/1946405857.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Date_reported']=='2021-01-11'][df['Country_code']=='BR'] #Original pandemic declaration
#       Date_reported Country_code Country WHO_region  New_cases
# 33862    2021-01-11           BR  Brazil       AMRO      62290  \
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 33862           8075998        1171             202631

# %%
df[df['Date_reported']=='2021-04-04'][df['Country_code']=='BR'] #Delta
# Out:
# /var/folders/mn/7pmlfsp175s9b73sjyf7qyvc0000gn/T/ipykernel_4196/1048867974.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Date_reported']=='2021-04-04'][df['Country_code']=='BR'] #Delta
#       Date_reported Country_code Country WHO_region  New_cases
# 33945    2021-04-04           BR  Brazil       AMRO      70238  \
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 33945          12910082        2922             328206

# %%
df[df['Date_reported']=='2021-11-26'][df['Country_code']=='BR'] #Omicron
# Out:
# /var/folders/mn/7pmlfsp175s9b73sjyf7qyvc0000gn/T/ipykernel_4196/2294091965.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Date_reported']=='2021-11-26'][df['Country_code']=='BR'] #Omicron
#       Date_reported Country_code Country WHO_region  New_cases
# 34181    2021-11-26           BR  Brazil       AMRO      12930  \
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 34181          22043112         273             613339

# %%
(df[df['Country_code']=='BR']['Cumulative_deaths'] / df[df['Country_code']=='BR']['Cumulative_cases']).dropna()
# Out:
# 33543    0.000000
# 33544    0.000000
# 33545    0.000000
# 33546    0.000000
# 33547    0.000000
#            ...
# 34679    0.018794
# 34680    0.018772
# 34681    0.018772
# 34682    0.018772
# 34683    0.018772
# Length: 1141, dtype: float64

# %%
plt.plot((df[df['Country_code']=='BR']['New_cases']).dropna())
plt.title('New cases of SARS-CoV-2 in BRAZIL')
#Pandemic Declaration
plt.axvline(x=33556, color='k', linestyle='--')
#Alpha
plt.axvline(x=33838, color='k', linestyle='--')
#Gamma
plt.axvline(x=33862, color='k', linestyle='--')
#Delta
plt.axvline(x=33945, color='k', linestyle='--')
#Omicron
plt.axvline(x=34181, color='k', linestyle='--')
plt.savefig('./Figures/BR_nc.png', dpi=500)
plt.show()

# %%
plt.plot(df[df['Country_code']=='BR']['New_deaths'])
plt.title('New deaths of SARS-CoV-2 in BRAZIL')
#Pandemic Declaration
plt.axvline(x=33556, color='k', linestyle='--')
#Alpha
plt.axvline(x=33838, color='k', linestyle='--')
#Gamma
plt.axvline(x=33862, color='k', linestyle='--')
#Delta
plt.axvline(x=33945, color='k', linestyle='--')
#Omicron
plt.axvline(x=34181, color='k', linestyle='--')
plt.savefig('./Figures/BR_nd.png', dpi=500)
plt.show()

# %%
plt.plot((df[df['Country_code']=='BR']['New_deaths'] / df[df['Country_code']=='BR']['New_cases']).dropna())
plt.title('Fatality rate of SARS-CoV-2 in BRAZIL')
#Pandemic Declaration
plt.axvline(x=33556, color='k', linestyle='--')
#Alpha
plt.axvline(x=33838, color='k', linestyle='--')
#Gamma
plt.axvline(x=33862, color='k', linestyle='--')
#Delta
plt.axvline(x=33945, color='k', linestyle='--')
#Omicron
plt.axvline(x=34181, color='k', linestyle='--')
plt.savefig('./Figures/BR_dr.png', dpi=500)
plt.show()
