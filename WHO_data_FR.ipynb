# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('WHO-COVID-19-global-data.csv')
df.loc[df['New_deaths'] < 0, 'New_deaths'] = 0
df.loc[df['New_cases'] < 0, 'New_cases'] = 0

# %%
df[df['Country_code']=='FR']
# Out:
#       Date_reported Country_code Country WHO_region  New_cases
# 86112    2020-01-03           FR  France       EURO          0  \
# 86113    2020-01-04           FR  France       EURO          0
# 86114    2020-01-05           FR  France       EURO          0
# 86115    2020-01-06           FR  France       EURO          0
# 86116    2020-01-07           FR  France       EURO          0
# ...             ...          ...     ...        ...        ...
# 87303    2023-04-08           FR  France       EURO       8786
# 87304    2023-04-09           FR  France       EURO       7739
# 87305    2023-04-10           FR  France       EURO       6474
# 87306    2023-04-11           FR  France       EURO       1342
# 87307    2023-04-12           FR  France       EURO          0
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 86112                 0           0                  0
# 86113                 0           0                  0
# ...

# %%
df[df['Date_reported']=='2020-03-11'][df['Country_code']=='FR'] #Original pandemic declaration
# Out:
# /var/folders/mn/7pmlfsp175s9b73sjyf7qyvc0000gn/T/ipykernel_7423/2397550471.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Date_reported']=='2020-03-11'][df['Country_code']=='FR'] #Original pandemic declaration
#       Date_reported Country_code Country WHO_region  New_cases
# 86180    2020-03-11           FR  France       EURO        372  \
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 86180              1774           3                 33

# %%
df[df['Date_reported']=='2020-12-18'][df['Country_code']=='FR'] #Alpha
# Out:
# /var/folders/mn/7pmlfsp175s9b73sjyf7qyvc0000gn/T/ipykernel_7423/274191980.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Date_reported']=='2020-12-18'][df['Country_code']=='FR'] #Alpha
#       Date_reported Country_code Country WHO_region  New_cases
# 86462    2020-12-18           FR  France       EURO      10452  \
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 86462           2403003         256              59245

# %%
df[df['Date_reported']=='2021-01-11'][df['Country_code']=='FR'] #Gamma
# Out:
# /var/folders/mn/7pmlfsp175s9b73sjyf7qyvc0000gn/T/ipykernel_7423/1550227377.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Date_reported']=='2021-01-11'][df['Country_code']=='FR'] #Gamma
#       Date_reported Country_code Country WHO_region  New_cases
# 86486    2021-01-11           FR  France       EURO      20189  \
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 86486           2746671         151              67368

# %%
df[df['Date_reported']=='2021-04-04'][df['Country_code']=='FR'] #Delta
# Out:
# /var/folders/mn/7pmlfsp175s9b73sjyf7qyvc0000gn/T/ipykernel_7423/704861465.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Date_reported']=='2021-04-04'][df['Country_code']=='FR'] #Delta
#       Date_reported Country_code Country WHO_region  New_cases
# 86569    2021-04-04           FR  France       EURO       8602  \
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 86569           4507422         185              95844

# %%
df[df['Date_reported']=='2021-11-26'][df['Country_code']=='FR'] #Omicron
# Out:
# /var/folders/mn/7pmlfsp175s9b73sjyf7qyvc0000gn/T/ipykernel_7423/3663522494.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df['Date_reported']=='2021-11-26'][df['Country_code']=='FR'] #Omicron
#       Date_reported Country_code Country WHO_region  New_cases
# 86805    2021-11-26           FR  France       EURO      33320  \
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 86805           7285128          72             116314

# %%
(df[df['Country_code']=='FR']['Cumulative_deaths'] / df[df['Country_code']=='FR']['Cumulative_cases']).dropna()
# Out:
# 86133    0.000000
# 86134    0.000000
# 86135    0.000000
# 86136    0.000000
# 86137    0.000000
#            ...
# 87303    0.004182
# 87304    0.004182
# 87305    0.004181
# 87306    0.004181
# 87307    0.004181
# Length: 1175, dtype: float64

# %%
plt.plot((df[df['Country_code']=='FR']['New_cases']).dropna())
plt.title('New cases of SARS-CoV-2 in FRANCE')
#Pandemic Declaration
plt.axvline(x=86180, color='k', linestyle='--')
#Alpha
plt.axvline(x=86462, color='k', linestyle='--')
#Gamma
plt.axvline(x=86486, color='k', linestyle='--')
#Delta
plt.axvline(x=86569, color='k', linestyle='--')
#Omicron
plt.axvline(x=86805, color='k', linestyle='--')
plt.savefig('./Figures/FR_nc.png', dpi=500)
plt.show()

# %%
plt.plot(df[df['Country_code']=='FR']['New_deaths'])
plt.title('New deaths of SARS-CoV-2 in FRANCE')
#Pandemic Declaration
plt.axvline(x=86180, color='k', linestyle='--')
#Alpha
plt.axvline(x=86462, color='k', linestyle='--')
#Gamma
plt.axvline(x=86486, color='k', linestyle='--')
#Delta
plt.axvline(x=86569, color='k', linestyle='--')
#Omicron
plt.axvline(x=86805, color='k', linestyle='--')
plt.savefig('./Figures/FR_nd.png', dpi=500)
plt.show()

# %%
plt.plot((df[df['Country_code']=='FR']['New_deaths'] / df[df['Country_code']=='FR']['New_cases']).dropna())
plt.title('Fatality rate of SARS-CoV-2 in FRANCE')
#Pandemic Declaration
plt.axvline(x=86180, color='k', linestyle='--')
#Alpha
plt.axvline(x=86462, color='k', linestyle='--')
#Gamma
plt.axvline(x=86486, color='k', linestyle='--')
#Delta
plt.axvline(x=86569, color='k', linestyle='--')
#Omicron
plt.axvline(x=86805, color='k', linestyle='--')
plt.savefig('./Figures/FR_dr.png', dpi=500)
plt.show()
